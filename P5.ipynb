# %% [markdown]
# 1 - Escribe un código para instalar la versión 3.7.1 de la biblioteca matplotlib.

# %%
# !pip install matplotlib==3.7.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 76.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.1 which is incompatible.
# ...

# %% [markdown]
# 2 - Escribe un código para importar la biblioteca numpy con el alias np.

# %%
import numpy as np

# %% [markdown]
# 3 - Crea un programa que lea la siguiente lista de números y elija uno al azar.
# lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]

# %%
import random as rd
lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]
print(rd.choice(lista))
# Out:
# 54

# %% [markdown]
# 4 - Crea un programa que genere aleatoriamente un número entero menor que 100.

# %%
print(rd.randrange(100))
# Out:
# 39

# %% [markdown]
# 5 - Crea un programa que solicite a la persona usuaria ingresar dos números enteros y calcule la potencia del primer número elevado al segundo.

# %%
print(f'Este programa calcula la potencia de un numero "a" elevado a la potencia "b"\n a^b')
numeroA = float(input('Ingresa el numero a: '))
numeroB = float(input('Ingresa el numero b: '))
print(f'El resultado de {numeroA}^{numeroB} es: {numeroA**numeroB}')
# Out:
# Este programa calcula la potencia de un numero "a" elevado a la potencia "b"
#  a^b
# Ingresa el numero a: 2.5
# Ingresa el numero b: 5
# El resultado de 2.5^5.0 es: 97.65625

# %% [markdown]
# 6 - Se debe escribir un programa para sortear a un seguidor de una red social para ganar un premio. La lista de participantes está numerada y debemos elegir aleatoriamente un número según la cantidad de participantes. Pide a la persona usuaria que proporcione el número de participantes del sorteo y devuelve el número sorteado.

# %%
participantes= int(input('Inrgesa el numero de partiipantes de la rifa: '))
print(f'El participante ganador es {rd.randrange(participantes)}')
# Out:
# Inrgesa el numero de partiipantes de la rifa: 50
# El participante ganador es 24

# %% [markdown]
# 7 - Has recibido una solicitud para generar números de token para acceder a la aplicación de una empresa. El token debe ser par y variar de 1000 a 9998. Escribe un código que solicite el nombre de la persona usuaria y muestre un mensaje junto a este token generado aleatoriamente.
#
# `
# print(f"Hola, {nombre_usuario}, tu token de acceso es {token_generado} ¡Bienvenido/a!")
# `

# %%
nombreUsurario = input('Ingresa el nombre de usuario:')
token = rd.randrange(1000,9998,1)
print(f'Aloha, {nombreUsurario}, tu token de acceso es {token} !Bienbenido/a')
# Out:
# Ingresa el nombre de usuario:JeraGod
# Aloha, JeraGod, tu token de acceso es 4132 !Bienbenido/a

# %% [markdown]
# 8 - Para diversificar y atraer nuevos clientes, una lanchonete creó un ítem misterioso en su menú llamado "ensalada de frutas sorpresa". En este ítem, se eligen aleatoriamente 3 frutas de una lista de 12 para componer la ensalada de frutas del cliente. Crea el código que realice esta selección aleatoria según la lista dada.

# %%
listaFrutas = ['uva', 'pera','mandarina', 'zarzamora','franbuesa','naranja','piña','aguacate', 'fresa', 'sandia','maracuya','manzana']
print(f'Tu ensalada de frutas salvaje estara compuesta por {rd.choices(listaFrutas,k=3)}')
# Out:
# Tu ensalada de frutas salvaje estara compuesta por ['zarzamora', 'mandarina', 'fresa']

# %% [markdown]
# 9 - Has recibido un desafío para calcular la raíz cuadrada de una lista de números, identificando cuáles resultan en un número entero. La lista es la siguiente:
#
# `
# numeros = [2, 8, 15, 23, 91, 112, 256]
# `

# %%
from math import sqrt
numeros = [2, 8, 15, 23, 91, 112, 256]
raizEnteros = []
for numero in numeros:
  if sqrt(numero)%1 == 0:
    raizEnteros.append(numero)
print(f'Los numoes que tienen raiz entera son {raizEnteros}')
# Out:
# Los numoes que tienen raiz entera son [256]

# %% [markdown]
# 10 - Haz un programa para una tienda que vende césped para jardines. Esta tienda trabaja con jardines circulares y el precio del metro cuadrado de césped es de R$ 25,00. Pide a la persona usuaria el radio del área circular y devuelve el valor en reales de cuánto tendrá que pagar.

# %%
from math import pi
radio = float(input('¿Cual es el radio del cesped?'))
print(f'El costo del jardin es: $ {round(pi*radio*radio*25.01,2)}')
# Out:
# ¿Cual es el radio del cesped?10
# El costo del jardin es: $ 7853.98
